# %% [markdown]
# # SMS Spam Detection - Model Experiment
# Notebook ini digunakan sebagai bukti eksperimen model untuk project akhir. Dataset yang dipakai adalah `backend/data/spam.csv` dari Kaggle.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path('..').resolve()
sys.path.append(str(PROJECT_ROOT / 'backend'))
from app.ml_service import train_models, load_metrics

# %% [markdown]
# ## Training model

# %%
metrics = train_models(test_size=0.2, random_state=42, max_features=8000)
metrics['best_model']

# %% [markdown]
# ## Hasil evaluasi

# %%
import pandas as pd
pd.DataFrame(metrics['models'])[[
    'model_name','accuracy','precision','recall','f1_score','roc_auc','pr_auc','log_loss','brier_score','final_score'
]]

# %% [markdown]
# ## McNemar Test

# %%
metrics['mcnemar_test']
